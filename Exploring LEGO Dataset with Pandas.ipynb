# %% [markdown]
# # LEGO Data Analysis - Rebrickable

# %% [markdown]
# The dataset is from https://rebrickable.com/downloads/.
#
# From the Rebrickable website - "The LEGO Parts/Sets/Colors and Inventories of every official LEGO set in the Rebrickable database is available for download as csv files here. These files are automatically updated daily. If you need more details, you can use the API which provides real-time data, but has rate limits that prevent bulk downloading of data."
#
# Rebrickable provides this database to be used for any purpose.

# %% [markdown]
# # Lego Data Model

# %% [markdown]
# ![downloads_schema_v3.JPG](attachment:downloads_schema_v3.JPG)

# %%
#import libraries

import pandas as pd
import numpy as np

# %%
pwd
# Out:
# '/Users/apple'

# %%
#Finding the directory

import os
os.getcwd()
# Out:
# '/Users/apple'

# %%
variable = pd.read_csv(r"/Users/apple/Downloads/data source/sets.csv")
variable.head
# Out:
# <bound method NDFrame.head of            set_num                             name  year  theme_id  num_parts
# 0            001-1                            Gears  1965         1         43
# 1           0011-2                Town Mini-Figures  1979        67         12
# 2           0011-3       Castle 2 for 1 Bonus Offer  1987       199          0
# 3           0012-1               Space Mini-Figures  1979       143         12
# 4           0013-1               Space Mini-Figures  1979       143         12
# ...            ...                              ...   ...       ...        ...
# 18944      XWING-1              Mini X-Wing Fighter  2019       158         60
# 18945      XWING-2                X-Wing Trench Run  2019       158         52
# 18946  YODACHRON-1  Yoda Chronicles Promotional Set  2013       158        413
# 18947   YTERRIER-1                Yorkshire Terrier  2018       598          0
# 18948     ZX8000-1             ZX 8000 LEGO Sneaker  2020       501          0
#
# [18949 rows x 5 columns]>

# %%
#Getting the data

sets = pd.read_csv("/Users/apple/Downloads/data source/sets.csv")
sets
# Out:
#            set_num                             name  year  theme_id  num_parts
# 0            001-1                            Gears  1965         1         43
# 1           0011-2                Town Mini-Figures  1979        67         12
# 2           0011-3       Castle 2 for 1 Bonus Offer  1987       199          0
# 3           0012-1               Space Mini-Figures  1979       143         12
# 4           0013-1               Space Mini-Figures  1979       143         12
# ...            ...                              ...   ...       ...        ...
# 18944      XWING-1              Mini X-Wing Fighter  2019       158         60
# 18945      XWING-2                X-Wing Trench Run  2019       158         52
# 18946  YODACHRON-1  Yoda Chronicles Promotional Set  2013       158        413
# 18947   YTERRIER-1                Yorkshire Terrier  2018       598          0
# 18948     ZX8000-1             ZX 8000 LEGO Sneaker  2020       501          0
#
# [18949 rows x 5 columns]

# %%
themes = pd.read_csv("/Users/apple/Downloads/data source/themes.csv")
themes
# Out:
#       id                        name  parent_id
# 0      1                     Technic        NaN
# 1      3                 Competition        1.0
# 2      4              Expert Builder        1.0
# 3     16                  RoboRiders        1.0
# 4     17              Speed Slammers        1.0
# ..   ...                         ...        ...
# 439  715                      Marvel      535.0
# 440  716                     Modulex        NaN
# 441  717                 Speed Racer        NaN
# 442  718       Series 22 Minifigures      535.0
# 443  719  BrickLink Designer Program        NaN
#
# [444 rows x 3 columns]

# %%
#Display the Top 10 rows of the sets dataset

sets.head(10)
# Out:
#   set_num                            name  year  theme_id  num_parts
# 0   001-1                           Gears  1965         1         43
# 1  0011-2               Town Mini-Figures  1979        67         12
# 2  0011-3      Castle 2 for 1 Bonus Offer  1987       199          0
# 3  0012-1              Space Mini-Figures  1979       143         12
# 4  0013-1              Space Mini-Figures  1979       143         12
# 5  0014-1              Space Mini-Figures  1979       143         12
# 6  0015-1              Space Mini-Figures  1979       143         18
# 7  0016-1             Castle Mini Figures  1979       186         15
# 8   002-1  4.5V Samsonite Gears Motor Set  1965         1          3
# 9   003-1             Master Mechanic Set  1966       366        403

# %%
#Display the Last 10 rows of the sets dataset

sets.tail(10)
# Out:
#            set_num                              name  year  theme_id  \
# 18939   XBOXGAME-1   Batman the Videogame - Xbox 360  2008       501
# 18940   XBOXGAME-2        Bionicle Heroes - Xbox 360  2006       501
# 18941   XBOXGAME-3      DC Super-Villains - Xbox One  2018       501
# 18942   XBOXGAME-9  Star Wars: The Video Game - Xbox  2005       501
# 18943   XMASTREE-1                    Christmas Tree  2019       410
# 18944      XWING-1               Mini X-Wing Fighter  2019       158
# 18945      XWING-2                 X-Wing Trench Run  2019       158
# 18946  YODACHRON-1   Yoda Chronicles Promotional Set  2013       158
# 18947   YTERRIER-1                 Yorkshire Terrier  2018       598
# 18948     ZX8000-1              ZX 8000 LEGO Sneaker  2020       501
#
#        num_parts
# 18939          0
# 18940          0
# 18941          0
# 18942          0
# 18943         26
# 18944         60
# 18945         52
# 18946        413
# 18947          0
# 18948          0

# %%
#Check Datatype of each column

sets.dtypes
# Out:
# set_num      object
# name         object
# year          int64
# theme_id      int64
# num_parts     int64
# dtype: object

# %%
#Check NULL Values in sets 

sets.isnull().sum()
# Out:
# set_num      0
# name         0
# year         0
# theme_id     0
# num_parts    0
# dtype: int64

# %%
#Check NULL Values in themes

themes.isnull().sum()
# Out:
# id             0
# name           0
# parent_id    138
# dtype: int64

# %%
#How many rows and columns available in the dataset

sets.shape
# Out:
# (18949, 5)

# %%
sets.columns
len(sets.columns)
# Out:
# 5

# %%
len(sets)
# Out:
# 18949

# %%
sets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18949 entries, 0 to 18948
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   set_num    18949 non-null  object
#  1   name       18949 non-null  object
#  2   year       18949 non-null  int64
#  3   theme_id   18949 non-null  int64
#  4   num_parts  18949 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 740.3+ KB

# %%
#Merge Data
#Joining the two datasets to answer questions

# %%
sets_themes = pd.merge(sets, themes, how = 'left', left_on = 'theme_id', right_on = 'id', suffixes = ('_sets','_themes'))

# %%
sets_themes.head()
# Out:
#   set_num                   name_sets  year  theme_id  num_parts   id  \
# 0   001-1                       Gears  1965         1         43    1
# 1  0011-2           Town Mini-Figures  1979        67         12   67
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987       199          0  199
# 3  0012-1          Space Mini-Figures  1979       143         12  143
# 4  0013-1          Space Mini-Figures  1979       143         12  143
#
#     name_themes  parent_id
# 0       Technic        NaN
# 1  Classic Town       50.0
# 2  Lion Knights      186.0
# 3  Supplemental      126.0
# 4  Supplemental      126.0

# %%
sets_themes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18949 entries, 0 to 18948
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   set_num      18949 non-null  object
#  1   name_sets    18949 non-null  object
#  2   year         18949 non-null  int64
#  3   theme_id     18949 non-null  int64
#  4   num_parts    18949 non-null  int64
#  5   id           18949 non-null  int64
#  6   name_themes  18949 non-null  object
#  7   parent_id    8675 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 1.3+ MB

# %%
sets_themes.columns
# Out:
# Index(['set_num', 'name_sets', 'year', 'theme_id', 'num_parts', 'id',
#        'name_themes', 'parent_id'],
#       dtype='object')

# %% [markdown]
# # Now let us answer some questions

# %%
# 1. What is the total number of parts per theme

# %%
Num_Parts_per_theme = sets_themes.groupby('name_themes').sum().reset_index()
Num_Parts_per_theme = Num_Parts_per_theme[['name_themes','num_parts']].sort_values('num_parts',ascending = False)
Num_Parts_per_theme
# Out:
#         name_themes  num_parts
# 303         Technic     221215
# 292       Star Wars     220924
# 66   Creator Expert     128830
# 64          Creator     102357
# 209         Ninjago      96604
# ..              ...        ...
# 16         Aquazone         26
# 354         Zooters         25
# 229      Powered Up         21
# 339     Value Packs          1
# 6       Adventurers          0
#
# [356 rows x 2 columns]

# %%
# 2. What is the total number of parts per year

# %%
Num_Parts_per_Year = sets_themes.groupby('year').sum().reset_index()
Num_Parts_per_Year = Num_Parts_per_Year[['year','num_parts']].sort_values('num_parts',ascending = False)
Num_Parts_per_Year
# Out:
#     year  num_parts
# 70  2021     264830
# 69  2020     211846
# 68  2019     191506
# 66  2017     178606
# 67  2018     171716
# ..   ...        ...
# 5   1956        246
# 3   1954        117
# 8   1959         65
# 2   1953         50
# 1   1950          6
#
# [72 rows x 2 columns]

# %%
# 3. How many sets where created in each century in the dataset
#We have to add century as a derived column to the sets_themes dataset

# %%
unique_year = sets_themes['year'].unique()
unique_year.sort()
unique_year
# Out:
# array([1949, 1950, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
#        1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972,
#        1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020, 2021, 2022])

# %%
sets_themes['year'] > 2000
sets_themes['Century'] = np.where(sets_themes['year'] > 2000, '21st_Century', '20th_Century')

# %%
sets_themes
# Out:
#            set_num                        name_sets  year  theme_id  \
# 0            001-1                            Gears  1965         1
# 1           0011-2                Town Mini-Figures  1979        67
# 2           0011-3       Castle 2 for 1 Bonus Offer  1987       199
# 3           0012-1               Space Mini-Figures  1979       143
# 4           0013-1               Space Mini-Figures  1979       143
# ...            ...                              ...   ...       ...
# 18944      XWING-1              Mini X-Wing Fighter  2019       158
# 18945      XWING-2                X-Wing Trench Run  2019       158
# 18946  YODACHRON-1  Yoda Chronicles Promotional Set  2013       158
# 18947   YTERRIER-1                Yorkshire Terrier  2018       598
# 18948     ZX8000-1             ZX 8000 LEGO Sneaker  2020       501
#
#        num_parts   id   name_themes  parent_id       Century
# 0             43    1       Technic        NaN  20th_Century
# 1             12   67  Classic Town       50.0  20th_Century
# 2              0  199  Lion Knights      186.0  20th_Century
# 3             12  143  Supplemental      126.0  20th_Century
# 4             12  143  Supplemental      126.0  20th_Century
# ...          ...  ...           ...        ...           ...
# 18944         60  158     Star Wars        NaN  21st_Century
# 18945         52  158     Star Wars        NaN  21st_Century
# 18946        413  158     Star Wars        NaN  21st_Century
# 18947          0  598   Promotional        NaN  21st_Century
# 18948          0  501          Gear        NaN  21st_Century
#
# [18949 rows x 9 columns]

# %%
Num_set_per_Century = sets_themes.groupby('Century').count().reset_index()
Num_set_per_Century [['Century','set_num']]
# Out:
#         Century  set_num
# 0  20th_Century     4858
# 1  21st_Century    14091

# %%
# 4. What percentage of sets ever released in the 21st Century were Trains Themed

# %%
Century_21_Data = sets_themes[sets_themes['Century'] == '21st_Century']
Train = Century_21_Data[Century_21_Data['name_themes'].str.contains('Train')]

# %%
Century_21_Data.shape[0]
# Out:
# 14091

# %%
Train.shape[0]
# Out:
# 63

# %%
Train.shape[0] / Century_21_Data.shape[0] * 100
# Out:
# 0.44709388971684055

# %%
# 5. What percentage of sets ever released in the 21st Century were Disney Themed

# %%
Disney = Century_21_Data[Century_21_Data['name_themes'].str.contains('Disney')]
Disney
# Out:
#                    set_num                   name_sets  year  theme_id  \
# 416                10509-1              Dusty and Chug  2013       627
# 418                10510-1       Ripslinger's Air Race  2013       627
# 419                10511-1     Skipper's Flight School  2013       627
# 423                10515-1     Ariel's Undersea Castle  2013       640
# 424                10516-1   Ariel's Magical Boat Ride  2012       640
# ...                    ...                         ...   ...       ...
# 12365              71044-1    Disney Train and Station  2019       608
# 17952  CINDERELLASCASTLE-1         Cinderella’s Castle  2017       608
# 18757               ROSE-1  The Beast's Enchanted Rose  2017       608
# 18853       TRUCOGSWORTH-1                   Cogsworth  2016       608
# 18863         TRULUMIERE-1                     Lumiere  2016       608
#
#        num_parts   id      name_themes  parent_id       Century
# 416           16  627    Disney Planes      504.0  21st_Century
# 418           40  627    Disney Planes      504.0  21st_Century
# 419           53  627    Disney Planes      504.0  21st_Century
# 423           39  640  Disney Princess      504.0  21st_Century
# 424           30  640  Disney Princess      504.0  21st_Century
# ...          ...  ...              ...        ...           ...
# 12365       2927  608           Disney        NaN  21st_Century
# 17952        102  608           Disney        NaN  21st_Century
# 18757          0  608           Disney        NaN  21st_Century
# 18853         48  608           Disney        NaN  21st_Century
# 18863         24  608           Disney        NaN  21st_Century
#
# [176 rows x 9 columns]

# %%
Disney.shape[0]
# Out:
# 176

# %%
Disney.shape[0] /  Century_21_Data.shape[0] * 100
# Out:
# 1.249024199843872

# %%
# 6. What is the popular theme by year in terms of sets released in the 21st Century

# %%
Popular_Theme_per_Year = Century_21_Data.groupby(['year', 'name_themes']).count().reset_index()
Popular_Theme_per_Year = Popular_Theme_per_Year[['year', 'name_themes', 'set_num']].sort_values('set_num', ascending = False)
Popular_Theme_per_Year.drop_duplicates('year').sort_values('year', ascending = False)
# Out:
#       year  name_themes  set_num
# 1406  2022  Super Mario       27
# 1327  2021         Gear      226
# 1252  2020         Gear      150
# 1181  2019         Gear      173
# 1104  2018         Gear      115
# 1035  2017         Gear      141
# 953   2016         Gear       98
# 866   2015         Gear       87
# 786   2014         Gear       97
# 707   2013         Gear       94
# 632   2012         Gear      105
# 566   2011         Gear      102
# 509   2010         Gear       59
# 454   2009         Gear      104
# 400   2008         Gear       84
# 343   2007         Gear      109
# 289   2006         Gear       75
# 214   2005     Bionicle       36
# 165   2004     Bionicle       48
# 109   2003     Bionicle       63
# 96    2002      Technic       65
# 6     2001     Bionicle       47

# %%
# 7. What is the most produced color of lego ever in terms of quantity of parts

# %%
colors = pd.read_csv("/Users/apple/Downloads/data source/colors.csv")
colors
# Out:
#        id                  name     rgb is_trans
# 0      -1             [Unknown]  0033B2        f
# 1       0                 Black  05131D        f
# 2       1                  Blue  0055BF        f
# 3       2                 Green  237841        f
# 4       3        Dark Turquoise  008F9B        f
# ..    ...                   ...     ...      ...
# 211  1085       Two-tone Silver  737271        f
# 212  1086            Pearl Lime  6A7944        f
# 213  1087            Duplo Pink  FF879C        f
# 214  1088          Medium Brown  755945        f
# 215  9999  [No Color/Any Color]  05131D        f
#
# [216 rows x 4 columns]

# %%
inventory_parts = pd.read_csv("/Users/apple/Downloads/data source/inventory_parts.csv")
inventory_parts
# Out:
#          inventory_id        part_num  color_id  quantity is_spare
# 0                   1        48379c01        72         1        f
# 1                   1           48395         7         1        f
# 2                   1  stickerupn0077      9999         1        f
# 3                   1         upn0342         0         1        f
# 4                   1         upn0350        25         1        f
# ...               ...             ...       ...       ...      ...
# 1007999        130491            6141        46         2        f
# 1008000        130491            6141        36        11        f
# 1008001        130491            6141        15        39        f
# 1008002        130491            6141        47        22        f
# 1008003        130491        73194c01         0         2        f
#
# [1008004 rows x 5 columns]

# %%
color_inventory = pd.merge(inventory_parts, colors, how = 'left', left_on = 'color_id', right_on = 'id')
color_inventory
# Out:
#          inventory_id        part_num  color_id  quantity is_spare    id  \
# 0                   1        48379c01        72         1        f    72
# 1                   1           48395         7         1        f     7
# 2                   1  stickerupn0077      9999         1        f  9999
# 3                   1         upn0342         0         1        f     0
# 4                   1         upn0350        25         1        f    25
# ...               ...             ...       ...       ...      ...   ...
# 1007999        130491            6141        46         2        f    46
# 1008000        130491            6141        36        11        f    36
# 1008001        130491            6141        15        39        f    15
# 1008002        130491            6141        47        22        f    47
# 1008003        130491        73194c01         0         2        f     0
#
#                          name     rgb is_trans
# 0            Dark Bluish Gray  6C6E68        f
# 1                  Light Gray  9BA19D        f
# 2        [No Color/Any Color]  05131D        f
# 3                       Black  05131D        f
# 4                      Orange  FE8A18        f
# ...                       ...     ...      ...
# 1007999          Trans-Yellow  F5CD2F        t
# 1008000             Trans-Red  C91A09        t
# 1008001                 White  FFFFFF        f
# 1008002           Trans-Clear  FCFCFC        t
# 1008003                 Black  05131D        f
#
# [1008004 rows x 9 columns]

# %%
color_inventory.rename(columns = {'name': 'color_name'}, inplace = True)

# %%
color_inventory
# Out:
#          inventory_id        part_num  color_id  quantity is_spare    id  \
# 0                   1        48379c01        72         1        f    72
# 1                   1           48395         7         1        f     7
# 2                   1  stickerupn0077      9999         1        f  9999
# 3                   1         upn0342         0         1        f     0
# 4                   1         upn0350        25         1        f    25
# ...               ...             ...       ...       ...      ...   ...
# 1007999        130491            6141        46         2        f    46
# 1008000        130491            6141        36        11        f    36
# 1008001        130491            6141        15        39        f    15
# 1008002        130491            6141        47        22        f    47
# 1008003        130491        73194c01         0         2        f     0
#
#                    color_name     rgb is_trans
# 0            Dark Bluish Gray  6C6E68        f
# 1                  Light Gray  9BA19D        f
# 2        [No Color/Any Color]  05131D        f
# 3                       Black  05131D        f
# 4                      Orange  FE8A18        f
# ...                       ...     ...      ...
# 1007999          Trans-Yellow  F5CD2F        t
# 1008000             Trans-Red  C91A09        t
# 1008001                 White  FFFFFF        f
# 1008002           Trans-Clear  FCFCFC        t
# 1008003                 Black  05131D        f
#
# [1008004 rows x 9 columns]

# %%
Popular_Color = color_inventory.groupby('color_name').sum().reset_index()
Popular_Color = Popular_Color[['color_name', 'quantity']].sort_values('quantity', ascending = False)

Popular_Color.head(50)
# Out:
#                color_name  quantity
# 1                   Black    637940
# 59      Light Bluish Gray    379324
# 198                 White    375812
# 24       Dark Bluish Gray    267092
# 137                   Red    253762
# 2                    Blue    176904
# 199                Yellow    175280
# 155                   Tan    123832
# 138         Reddish Brown    104999
# 61             Light Gray    101663
# 55                  Green     64472
# 160           Trans-Clear     36981
# 121                Orange     36844
# 33               Dark Tan     36314
# 32               Dark Red     33720
# 22              Dark Blue     31879
# 73                   Lime     30447
# 127            Pearl Gold     30000
# 169      Trans-Light Blue     24202
# 26              Dark Gray     23855
# 183             Trans-Red     20646
# 45            Flat Silver     18333
# 83          Medium Nougat     16252
# 6     Bright Light Orange     16135
# 76           Medium Azure     15463
# 147            Sand Green     15266
# 4            Bright Green     13834
# 27             Dark Green     13809
# 25             Dark Brown     13696
# 179          Trans-Orange     12871
# 77            Medium Blue     12679
# 185          Trans-Yellow     12661
# 29            Dark Orange     11812
# 31            Dark Purple     11069
# 8             Bright Pink     10500
# 162       Trans-Dark Blue     10354
# 34         Dark Turquoise      9990
# 9                   Brown      9481
# 30              Dark Pink      8972
# 156           Trans-Black      8759
# 21             Dark Azure      8415
# 75                Magenta      8372
# 201  [No Color/Any Color]      7598
# 176      Trans-Neon Green      7447
# 177     Trans-Neon Orange      6389
# 126       Pearl Dark Gray      5783
# 130      Pearl Light Gray      5647
# 120           Olive Green      5637
# 146             Sand Blue      5296
# 167           Trans-Green      5209
